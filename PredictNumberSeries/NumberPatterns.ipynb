# %% [markdown]
# <a href="https://colab.research.google.com/github/prodramp/DeepWorks/blob/main/PredictNumberSeries/NumberPatterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Resources
# - https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.uniform.html
# - https://levelup.gitconnected.com/generating-random-data-from-continuous-functions-f0d7e9a909df

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Objective:**
# - Generate a sequence of numbers based on Function Y
# - Y = A Function which is based on x
# - x is a series of numbers based on uniform number distribution

# %%
n = 100
x = np.random.uniform(size=(n,1))  
y = np.sqrt(x)

# %%
print(len(y))
print(len(x))
#y
# Out:
# 100
# 100

# %% [markdown]
# Potting The results

# %%
fig, ax = plt.subplots(dpi=100, figsize=(15,5))
plt.scatter(x,y.ravel())

# %% [markdown]
# The use of ravel() function
# - Flatten the multidimension data to contiguous flattened array.

# %%
#y
y.ravel()
# Out:
# array([0.92865669, 0.02403125, 0.96614132, 0.39940753, 0.67601548,
#        0.98238913, 0.92454416, 0.9494749 , 0.74406892, 0.92048661,
#        0.02195186, 0.65308443, 0.87060855, 0.182149  , 0.67732371,
#        0.73871162, 0.46860716, 0.63240542, 0.96072813, 0.42736517,
#        0.66845284, 0.93085318, 0.45410381, 0.29007759, 0.52307364,
#        0.96271666, 0.53372093, 0.49283298, 0.68578131, 0.68627203,
#        0.77904278, 0.59353577, 0.96081051, 0.2197816 , 0.74749998,
#        0.25113   , 0.79324215, 0.31601931, 0.36704877, 0.47990121,
#        0.11516891, 0.98921437, 0.83761693, 0.43870425, 0.45243542,
#        0.37498582, 0.26714589, 0.58709118, 0.26196516, 0.22919943,
#        0.83179205, 0.48207296, 0.90436803, 0.40428571, 0.43857572,
#        0.79252633, 0.0297976 , 0.79794767, 0.421076  , 0.77228155,
#        0.29819089, 0.28495298, 0.18636814, 0.13023533, 0.46808815,
#        0.47968213, 0.83698786, 0.01648004, 0.99315613, 0.57559921,
# ...

# %% [markdown]
# Adding noice to the function
# - Random disturbance to the series

# %%
n = 1000
x = np.random.uniform(size=(n,1))  
noise = np.random.normal(0, 0.01, size=x.shape)
y = np.sqrt(x)
y = y + noise

# %%
fig, ax = plt.subplots(dpi=100, figsize=(15,5))
plt.scatter(x,y.ravel())

# %% [markdown]
# Using Functions

# %%
# Equation:: y = x*x
def generate_data_with_noise(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.square(x) 
  if is_noise:
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
def generate_numbers_plot(x,y):
  fig, ax = plt.subplots(dpi=100, figsize=(15,5))
  plt.scatter(x,y.ravel())

# %%
x,y = generate_data_with_noise(100, True)
generate_numbers_plot(x,y)

# %% [markdown]
# # **Experimenting with uniform vs expotential**

# %%
n = 1000
x = np.random.uniform(size=(n,1))  
#x = np.random.exponential(size=(n,1))  
y = np.square(x) + x + 1 # x*x + x + 1
noise = np.random.normal(0, 0.1, size=x.shape)
y = y #+ noise
generate_numbers_plot(x,y)

# %% [markdown]
# # **Plot to show both graphs side by side**

# %%
def side_by_side_plots(title, x1,y1, x2,y2):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
  fig.suptitle(title)
  ax1.scatter(x1, y1.ravel())
  ax2.scatter(x2, y2.ravel())

# %% [markdown]
# # **Equation: x2**

# %%
# Equation:: y = x*x 
def generate_data_with_noise_0(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.square(x)
  if is_noise:
    noise = np.random.normal(0, 0.01, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_data_with_noise_0(100, False)
x2,y2 = generate_data_with_noise_0(100, True)
side_by_side_plots('x*x', x1,y1, x2,y2)

# %% [markdown]
# # Equation:: y = x*x + x + 1

# %%
# Equation:: y = x*x + x + 1
def generate_data_with_noise_1(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.square(x) + x + 1
  if is_noise:
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_data_with_noise_1(100, False)
x2,y2 = generate_data_with_noise_1(100, True)
side_by_side_plots('x*x + x + 1', x1,y1, x2,y2)

# %% [markdown]
# # Equation:: y = -x*x - x - 1

# %%
# Equation:: y = -x*x - x - 1
def generate_data_with_noise_2(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = -np.square(x) - x - 1
  if is_noise:
    # reduce range from 0 to 0.01 to make the sharper curve
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_data_with_noise_2(100, False)
x2,y2 = generate_data_with_noise_2(100, True)
side_by_side_plots('-x*x - x - 1', x1,y1, x2,y2)

# %%
# 
# Equation:: y = x²
def generate_data_with_noise_3(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.square(x) - (x + 1)
  if is_noise:
    # reduce range from 0 to 0.01 to make the sharper curve
    noise = np.random.normal(0, 0.01, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_data_with_noise_3(100, False)
x2,y2 = generate_data_with_noise_3(100, True)
side_by_side_plots('x*x - (x + const)', x1,y1, x2,y2)

# %%
# 
# Equation:: -x² + x + 2
def generate_data_with_noise_4(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = -np.square(x) + x + 1
  if is_noise:
    # reduce range from 0/1 to 0.1/0.01 to make the sharper curve
    noise = np.random.normal(0, 0.01, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_data_with_noise_4(100, False)
x2,y2 = generate_data_with_noise_4(100, True)
side_by_side_plots('-x*x - x - 1', x1,y1, x2,y2)

# %% [markdown]
# # **Exponential Function**

# %%
# -----
# Equation:: np.exp(x)
def generate_exponential_data_with_noise(n, is_noise):
  # Add range from 0 to 1/10
  x = np.random.uniform(0, 10, size=(n,1))  
  y = np.exp(x)
  if is_noise:
    # reduce range from 0/1 to 100/1000 to make the sharper curve
    noise = np.random.normal(0, 1000, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_exponential_data_with_noise(100, False)
x2,y2 = generate_exponential_data_with_noise(100, True)
side_by_side_plots('Exponential Curve', x1,y1, x2,y2)

# %% [markdown]
# # **Logarithmic Function**

# %%
# -----
# Equation:: np.log(x)
def generate_logarithmic_data_with_noise(n, is_noise):
  # Add range from 0 to 1/10
  x = np.random.uniform(0, 10, size=(n,1))  
  y = np.log(x)
  if is_noise:
    # reduce range from 0/1 to 100/1000 to make the sharper curve
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_logarithmic_data_with_noise(100, False)
x2,y2 = generate_logarithmic_data_with_noise(100, True)
side_by_side_plots('Logarithmic Curve (np.log(x))', x1,y1, x2,y2)

# %% [markdown]
# # **Trignometric Functions (Sin, Cos, Tan)**

# %%
# Trignometric - Sin/Cos/Tan > Sin
# Sin > np.sin(2 * np.pi * x)
def generate_sin_with_noise(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.sin(2*np.pi*x)
  if is_noise:
    # reduce range from 0/1 to 0.1/0.01 to make the sharper curve
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_sin_with_noise(100, False)
x2,y2 = generate_sin_with_noise(100, True)
side_by_side_plots('Sin Curve', x1,y1, x2,y2)

# %%
# Trignometric - Sin/Cos/Tan > Cos
# Cos > np.cos(2 * np.pi * x)
def generate_cos_with_noise(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.cos(2*np.pi*x)
  if is_noise:
    # reduce range from 0/1 to 0.1/0.01 to make the sharper curve
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_cos_with_noise(100, False)
x2,y2 = generate_cos_with_noise(100, True)
side_by_side_plots('Cos Curve', x1,y1, x2,y2)

# %%
# Trignometric - Sin/Cos/Tan > Tan
# Tan > np.arctan(2 * np.pi * x)
def generate_tan_with_noise(n, is_noise):
  x = np.random.uniform(size=(n,1))  
  y = np.arctan(2*np.pi*x)
  if is_noise:
    # reduce range from 0/1 to 0.1/0.01 to make the sharper curve
    noise = np.random.normal(0, 0.1, size=x.shape)
    y = y + noise
  return (x, y)

# %%
x1,y1 = generate_tan_with_noise(100, False)
x2,y2 = generate_tan_with_noise(100, True)
side_by_side_plots('Tan Curve', x1,y1, x2,y2)
