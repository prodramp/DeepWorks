# %% [markdown]
# <a href="https://colab.research.google.com/github/prodramp/DeepWorks/blob/main/CMDLine-Whisper/OpenAI_Whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-0if1c9_p
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-0if1c9_p
# ...

# %%
# !pip show whisper
# Out:
# Name: whisper
# Version: 1.0
# Summary: UNKNOWN
# Home-page: UNKNOWN
# Author: OpenAI
# Author-email: None
# License: UNKNOWN
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, ffmpeg-python, transformers, tqdm, torch, more-itertools
# Required-by:

# %%
# !whisper --help
# Out:
# usage: whisper [-h]
#                [--model {tiny.en,tiny,base.en,base,small.en,small,medium.en,medium,large}]
#                [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR] [--verbose VERBOSE]
#                [--task {transcribe,translate}]
# ...

# %%
file_name = "/content/source_files/story.mp3"

# %%
from IPython.display import Audio, display
display(Audio(file_name, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !whisper /content/source_files/story.mp3 --model medium
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x4dcc000 @  0x7f3a5afed1e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7f3a5abeac87 0x5b561a
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:07.680]  It was a Thursday, but it felt like a Monday to John, and John loved Mondays.
# [00:07.680 --> 00:14.200]  He thrived at work, he dismissed the old cliché of dreading Monday mornings and refused to
# [00:14.200 --> 00:20.920]  engage in water cooler complaints about the grind and the empty conversations that included
# [00:20.920 --> 00:22.600]  the family parry.
# [00:22.600 --> 00:23.760]  How was your weekend?
# [00:23.760 --> 00:24.760]  Too short.
# [00:24.760 --> 00:30.800]  John liked his work and was unshamed.

# %%
# !whisper /content/source_files/story.mp3 --model small
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:07.680]  It was a Thursday, but it felt like a Monday to John, and John loved Mondays.
# [00:07.680 --> 00:14.200]  He thrived at work, he dismissed the old cliché of treading Monday mornings and refused to
# [00:14.200 --> 00:20.920]  engage in a water cooler complaint about the grind, and the empty conversations that included
# [00:20.920 --> 00:22.600]  the family ferry.
# [00:22.600 --> 00:23.760]  How was your weekend?
# [00:23.760 --> 00:24.760]  Too short.
# [00:24.760 --> 00:31.320]  John liked his work and was unshamed.

# %%
# !whisper /content/source_files/story.mp3 --model medium --task translate --language en
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x637c000 @  0x7f35fd5c21e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7f35fd1bfc87 0x5b561a
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:07.680]  It was a Thursday, but it felt like a Monday to John, and John loved Mondays.
# [00:07.680 --> 00:14.200]  He thrived at work, he dismissed the old cliché of dreading Monday mornings and refused to
# [00:14.200 --> 00:20.920]  engage in water cooler complaints about the grind and the empty conversations that included
# [00:20.920 --> 00:22.600]  the family parry.
# [00:22.600 --> 00:23.600]  How was your weekend?
# [00:23.600 --> 00:24.600]  Too short?
# [00:24.600 --> 00:30.440]  Yes, John liked his work and was unshamed.

# %%
# !cat /content/story.mp3.txt
# Out:
# It was a Thursday, but it felt like a Monday to John, and John loved Mondays.
# He thrived at work, he dismissed the old cliché of dreading Monday mornings and refused to
# engage in water cooler complaints about the grind and the empty conversations that included
# the family parry.
# How was your weekend?
# Too short?
# Yes, John liked his work and was unshamed.

# %%
# !cat /content/story.mp3.vtt
# Out:
# WEBVTT
#
# 00:00.000 --> 00:07.680
# It was a Thursday, but it felt like a Monday to John, and John loved Mondays.
#
# 00:07.680 --> 00:14.200
# He thrived at work, he dismissed the old cliché of dreading Monday mornings and refused to
#
# 00:14.200 --> 00:20.920
# engage in water cooler complaints about the grind and the empty conversations that included
#
# 00:20.920 --> 00:22.600
# the family parry.
#
# 00:22.600 --> 00:23.600
# How was your weekend?
#
# 00:23.600 --> 00:24.600
# Too short?
#
# 00:24.600 --> 00:30.440
# Yes, John liked his work and was unshamed.

# %%
file_name = "/content/source_files/bharat.mp3"

# %%
from IPython.display import Audio, display
display(Audio(file_name, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !whisper /content/source_files/bharat.mp3 --model medium  --language hi
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x660e000 @  0x7f263fa8b1e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7f263f688c87 0x5b561a
# [00:00.000 --> 00:18.000]  भारत एक बहुत महत्पून देस है, यह हमारे लिए बहुत सौबहागे की बात है, कि भारत एक महत्पून देस है, भारत की राजधानी दिल्लि है, भारत में 30 राजे हैं, और भारत में रहने वाले भारत वसी कहलाते हैं.
# [00:18.000 --> 00:30.000]  यह बहुत ही अच्छी बात है कि भारत को भारत कहते हैं, इसका दुसरा नाम इंडिया भी है, और भारत बहुत ही विशाल सुम्रद्ध देस है.

# %%
# !whisper /content/source_files/bharat.mp3 --model medium  --language hi --task translate
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x635e000 @  0x7fd499adf1e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7fd4996dcc87 0x5b561a
# [00:00.000 --> 00:10.000]  India is a very important country. It is fortunate for us that India is an important country.
# [00:10.000 --> 00:18.000]  India's capital is Delhi. There are 30 states in India and the people living in India are called Bharatvasis.
# [00:18.000 --> 00:30.000]  It is a very good thing that India is called Bharat. Its second name is India and India is a very rich country.

# %%
# !cat /content/bharat.mp3.txt
# Out:
# India is a very important country. It is fortunate for us that India is an important country.
# India's capital is Delhi. There are 30 states in India and the people living in India are called Bharatvasis.
# It is a very good thing that India is called Bharat. Its second name is India and India is a very rich country.

# %%
# !cat /content/bharat.mp3.srt
# Out:
# 1
# 00:00:00,000 --> 00:00:10,000
# India is a very important country. It is fortunate for us that India is an important country.
#
# 2
# 00:00:10,000 --> 00:00:18,000
# India's capital is Delhi. There are 30 states in India and the people living in India are called Bharatvasis.
#
# 3
# 00:00:18,000 --> 00:00:30,000
# It is a very good thing that India is called Bharat. Its second name is India and India is a very rich country.

# %%
file_name = "/content/source_files/miyuki-koso.mp3"

# %%
from IPython.display import Audio, display
display(Audio(file_name, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !whisper /content/source_files/miyuki-koso.mp3 --model medium  --language ja
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x5824000 @  0x7fddc5f0e1e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7fddc5b0bc87 0x5b561a
# [00:00.000 --> 00:05.000] 音声メッセージが既存のウェブサイトを超えたコミュニケーションを実現。
# [00:05.000 --> 00:14.000] 目で見るだけだったウェブサイトに音声情報をインクルードすることで情報に新しい価値を与え、他者との差別化に効果を発揮します。
# [00:14.000 --> 00:22.000] また、文字やグラフィックだけでは伝えることの難しかった感情やニュアンスを表現し、ユーザーの興味と理解を深めます。
# [00:22.000 --> 00:30.000] 見る・聞く・理解するウェブサイトへ音声メッセージが人の心を動かします。

# %%
# !whisper /content/source_files/miyuki-koso.mp3 --model medium  --language ja --task translate
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x6246000 @  0x7fb7d232a1e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7fb7d1f27c87 0x5b561a
# [00:00.000 --> 00:05.000]  The voice message is able to communicate beyond the existing web site.
# [00:05.000 --> 00:09.000]  By including voice information on a web site that you can only see with your eyes,
# [00:09.000 --> 00:14.000]  it gives new value to the information and has the effect of differentiating it from others.
# [00:14.000 --> 00:20.000]  In addition, it expresses emotions and nuances that are difficult to convey only in words and graphics,
# [00:20.000 --> 00:22.000]  deepening the interest and understanding of the user.
# [00:22.000 --> 00:30.000]  The voice message moves people's hearts to the web site where you can see, hear, and understand.

# %%
file_name = "/content/source_files/Welcome.mp4"

# %%
# !whisper /content/source_files/Welcome.mp4 --model medium  --language en
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0x66ea000 @  0x7f16c9d2f1e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7f16c992cc87 0x5b561a
# [00:00.000 --> 00:06.400]  Hello everyone, my name is Avakash and you are welcome to my YouTube channel Program
# [00:06.400 --> 00:17.200]  Inc. which is also the name of my tech startup. In last 20 plus years, I enjoyed working in various
# [00:17.200 --> 00:24.720]  software development positions notably at Microsoft platform which is now Workday,
# [00:24.720 --> 00:32.560]  my own startup Big Data Perspective, H2O.ai, Mechanica Networks Japan,
# [00:32.560 --> 00:42.000]  Roombi and Huft Inc. I had opportunity to lead and develop some amazing products used by
# [00:42.000 --> 00:49.040]  professionals and businesses around the globe. Some of these products are Microsoft Azure,
# ...

# %%
# !whisper /content/source_files/Welcome.mp4 --model large  --language en
# Out:
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:17<00:00, 173MiB/s]
# tcmalloc: large alloc 3087007744 bytes == 0x53ae000 @  0x7fee645901e7 0x4b2150 0x5ac2ec 0x5dc6af 0x58ee9b 0x5901a3 0x5e3f6b 0x4d18aa 0x51b31c 0x58f2a7 0x51740e 0x5b41c5 0x58f49e 0x51837f 0x58f2a7 0x51740e 0x5b41c5 0x604133 0x606e06 0x606ecc 0x609aa6 0x64d332 0x64d4de 0x7fee6418dc87 0x5b561a
# [00:00.000 --> 00:06.480]  Hello everyone, my name is Avkash and you are welcome to my YouTube channel RobRamp
# [00:06.480 --> 00:11.160]  Inc. which is also the name of my tech startup.
# [00:11.160 --> 00:20.520]  In last 20 plus years, I enjoyed working in various software development positions, notably
# [00:20.520 --> 00:30.440]  at Microsoft, Plutfora which is now Workday, my own startup Big Data Perspective, H2O.AI,
# [00:30.440 --> 00:36.200]  Magnica Networks Japan, Chromeby and Huft Inc.
# [00:36.200 --> 00:43.240]  I had opportunity to lead and develop some amazing products used by professionals and
# ...
